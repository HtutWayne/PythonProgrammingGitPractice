# %%
import pandas as pd

# %%
df = pd.read_csv('HR_5000 Records.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5002 entries, 0 to 5001
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  5002 non-null   int64
#  1   Name Prefix             5002 non-null   object
#  2   First Name              5002 non-null   object
#  3   Middle Initial          5002 non-null   object
#  4   Last Name               5002 non-null   object
#  5   Gender                  5002 non-null   object
#  6   E Mail                  5002 non-null   object
#  7   Father's Name           5002 non-null   object
#  8   Mother's Name           5002 non-null   object
#  9   Mother's Maiden Name    5002 non-null   object
#  10  Date of Birth           5002 non-null   object
#  11  Time of Birth           5002 non-null   object
#  12  Age in Yrs.             5002 non-null   float64
#  13  Weight in Kgs.          5002 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# Emp ID                    0
# Name Prefix               0
# First Name                0
# Middle Initial            0
# Last Name                 0
# Gender                    0
# E Mail                    0
# Father's Name             0
# Mother's Name             0
# Mother's Maiden Name      0
# Date of Birth             0
# Time of Birth             0
# Age in Yrs.               0
# Weight in Kgs.            0
# Date of Joining           0
# Quarter of Joining        0
# Half of Joining           0
# Year of Joining           0
# Month of Joining          0
# Month Name of Joining     0
# Short Month               0
# Day of Joining            0
# DOW of Joining            0
# Short DOW                 0
# Age in Company (Years)    0
# Salary                    0
# Last % Hike               0
# SSN                       0
# Phone No.                 0
# Place Name                0
# County                    0
# City                      0
# State                     0
# ...

# %%
df.isnull()
# Out:
#       Emp ID  Name Prefix  First Name  Middle Initial  Last Name  Gender  \
# 0      False        False       False           False      False   False
# 1      False        False       False           False      False   False
# 2      False        False       False           False      False   False
# 3      False        False       False           False      False   False
# 4      False        False       False           False      False   False
# ...      ...          ...         ...             ...        ...     ...
# 4997   False        False       False           False      False   False
# 4998   False        False       False           False      False   False
# 4999   False        False       False           False      False   False
# 5000   False        False       False           False      False   False
# 5001   False        False       False           False      False   False
#
#       E Mail  Father's Name  Mother's Name  Mother's Maiden Name  ...    SSN  \
# ...

# %%
df.describe()
# Out:
#               Emp ID  Age in Yrs.  Weight in Kgs.  Year of Joining  \
# count    5002.000000  5002.000000     5002.000000      5002.000000
# mean   555273.252299    40.498685       59.974410      2007.326269
# std    256321.457855    11.365253       13.647978         8.836826
# min    111150.000000    21.010000       40.000000      1979.000000
# 25%    335493.500000    30.695000       50.000000      2002.000000
# 50%    555869.000000    40.615000       57.000000      2010.000000
# 75%    781240.750000    50.387500       70.000000      2015.000000
# max    999800.000000    60.000000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count       5002.000000     5002.000000             5002.000000
# mean           6.344062       15.724510                9.767133
# std            3.394093        8.766317                8.829119
# min            1.000000        1.000000                0.000000
# ...

# %%
df.head(6)
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  526540         Ms.  Angelique              K   Goodwin      F
# 1  859327         Ms.       Jeni              S   Shaffer      F
# 2  887387         Ms.     Donald              T    Farris      F
# 3  779497        Hon.     Steven              D    Rendon      M
# 4  896517        Drs.     Jenell              L   Almanza      F
# 5  220965        Mrs.     Almeta              Y  Brookins      F
#
#                         E Mail     Father's Name      Mother's Name  \
# 0  angelique.goodwin@gmail.com      Rick Goodwin     Dorian Goodwin
# 1       jeni.shaffer@gmail.com      Ryan Shaffer       Love Shaffer
# 2  donald.farris@bellsouth.net      Mauro Farris       Edyth Farris
# 3      steven.rendon@gmail.com      Elden Rendon      Angela Rendon
# 4     jenell.almanza@yahoo.com  Clifford Almanza     Vergie Almanza
# 5    almeta.brookins@gmail.com  Richard Brookins  Angelika Brookins
#
# ...

# %%
df.iloc[5,12]
# Out:
# 32.24

# %%
df.iloc[5,10]
# Out:
# '5/8/1985'

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
df.tail(5)
# Out:
#       Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 4997  488800         Mr.    Roberto              R    Harter      M
# 4998  428330        Hon.    Brittni              B       Cyr      F
# 4999  313027         Mr.     Gerald              J   Beaudry      M
# 5000  826852        Mrs.     Emilee              D     Emery      F
# 5001  948300         Ms.   Larhonda              G    Dozier      F
#
#                              E Mail    Father's Name    Mother's Name  \
# 4997  roberto.harter@exxonmobil.com    Murray Harter  Merideth Harter
# 4998      brittni.cyr@earthlink.net     Williams Cyr      Darleen Cyr
# 4999         gerald.beaudry@shaw.ca  Zachary Beaudry    Sadie Beaudry
# 5000         emilee.emery@gmail.com     Andres Emery     Lavina Emery
# 5001        larhonda.dozier@aol.com   Houston Dozier      Gene Dozier
#
#      Mother's Maiden Name  ...          SSN    Phone No.      Place Name  \
# ...

# %%
df.dtypes
# Out:
# Emp ID                      int64
# Name Prefix                object
# First Name                 object
# Middle Initial             object
# Last Name                  object
# Gender                     object
# E Mail                     object
# Father's Name              object
# Mother's Name              object
# Mother's Maiden Name       object
# Date of Birth              object
# Time of Birth              object
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Date of Joining            object
# Quarter of Joining         object
# Half of Joining            object
# Year of Joining             int64
# Month of Joining            int64
# Month Name of Joining      object
# Short Month                object
# Day of Joining              int64
# DOW of Joining             object
# Short DOW                  object
# Age in Company (Years)    float64
# Salary                      int64
# Last % Hike                object
# ...

# %%
a = "$ 3,000 "
z = a.strip()
z
# Out:
# '$ 3,000'
